# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('iq_cgpa_placement.csv')

# %%
df.head(2)
# Out:
#     IQ  CGPA  Placement
# 0  117  7.95          1
# 1  107  5.91          1

# %%
sns.scatterplot(df,x='IQ',y='CGPA',hue='Placement')
# Out:
# <Axes: xlabel='IQ', ylabel='CGPA'>
